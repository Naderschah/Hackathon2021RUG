# %% [markdown]
# # Copernicus Open Access Hub [1]
#
# Here we will be giving a general outline of how to download data from the Copernicus Open Access Hub using an API
#
# The data can also be accessed from: https://scihub.copernicus.eu/dhus/#/home
#
# Within it you can grab data from the following missions:
#
# - Sentinel-1   :   two identical radar imagery satellites in the same orbit, providing an all-weather, day-and-night supply of images of Earth’s surface [2]
# - Sentinel-2   :   two identical satellites in the same orbit, images land and coastal areas at high spatial resolution in the optical domain [3]
# - Sentinel-3   :   one satelite, measures sea surface topography, sea and land surface temperature, and ocean and land surface colour [4]
# - Sentinel-5P  :   Sentinel-5 Precursor mission to monitor our atmosphere, its intended use is air quality, ozone & UV radtiation, and climate monitoring & forcatsting measurements [5]
#
#
# A full introduction can be found here: https://scihub.copernicus.eu/userguide/WebHome

# %% [markdown]
# ### If you want you can explore this option, however it is recomended to follow copernicus_data_easy.ipynb as a package is used to withdraw data making interactions far less complex

# %% [markdown]
# ## First we wil focus on downloading the data
#
# To do this we will use OData, a data access protocoll build on HTTP and REST, we can communicate with it using an Application Program Interface (API)

# %%
import requests

#Enter log in data here, an account can be made here: https://www.copernicus.eu/en

user = ''
password = ''

#The base URL is:
service_root_uri = 'https://scihub.copernicus.eu/dhus/odata/v1'
#The first addative to the URL can be any of these
resource_paths = ['/Products','/DeletedProducts','/Collections']
#We will be using the Products resources to construct our uri (unique resource identifier)
uri = service_root_uri+ resource_paths[0]

    #If you were to request this data you will get a table with metadata about the individual products, but not much usefull for our purposes

# %% [markdown]
# ## Making Querries
#
# To narrow down your search we can use several querry options, to start our querry we must place the character '?' at the end of our uri
#
# In the next few cells we will see how different options work

# %%
    #Making Querries 
#To start the querry string we must add a question mark
uri += '?'
# The below are our querrrying options
querry_options = ['$format=',        # HTTP response type either xml or json
                  '$filter=',        # An expression or function that must return true for the entry to be returned
                  '$orderby=',       # According to what values to order the output data
                  '$select=',        # Request properties of entries
                  '$skip=',          # Number of records to skip 
                  '$top=',           # Maximum number of records to return
                  '$count=',         # Request a count of matching resources 
                  '$inlinecount=',   # Request the count with the data
                  '$expand='         # Include related resources 
                  ]

# %% [markdown]
# ## Format
#
# This option specifies the data output format,
#
# we will be using the json format, it is generally read as a dictionary object containing nested lists and dictionaries

# %%
formats = [
            'json',
            'atom',
            'xml',
            'application/metalink4%2Bxml',
            'text/csv'
          ]

uri += '$format=json'

# %% [markdown]
# when adding multiple filters one must seperate them by and, if you would like more options these need to be seperated by &
#
# ## Filter
#
# The filter option selects a subset of entries that satisfy the expression specified by the querry
#
# For a full explanation please go to the manual https://scihub.copernicus.eu/twiki/do/view/SciHubUserGuide/ODataAPI#URI_Components
#
# They can be found under OData System Querry $filter
#
# **Comparison operators**:
#
# - <   	lt   	    Lower than
#
# - ≤   	le   	    Lower or equal than
#
# - \>   	gt   	    Greater than
#
# - ≥   	ge   	    Greater or equal than
#
# - =   	eq   	    Equal
#
# - ≠   	ne   	    Not Equal
#
#
#
# **Date Built-in functions**:
# - IngestionDate
# - CreationDate
# - ContentDate/Start and ContentDate/End
#
# We can use the following identifiers:
# - **year**
# - **month**
# - **day**
# - **hour**
# - **minute**
# - **second**
# - **datetime**2
#
# **Example**:
#
# https://scihub.copernicus.eu/dhus/odata/v1/Products?$filter=**year(IngestionDate) eq 2017 and month(IngestionDate) eq 12**
#
#
# **Substring Built-in functions:**
# - substringof 	Returns records with names containing a particular string at any position
# - endswith 	The endswith function returns true if the first parameter string value ends with the second parameter string value, otherwise it returns false
# - startwith 	The startswith function returns true if the first parameter string value starts with the second parameter string value, otherwise it returns false
#
# **Examples:**
#
# This OData URI lists the products having SLC in the file name
#
# https://scihub.copernicus.eu/dhus/odata/v1/Products?$**filter=substringof('SLC',Name)**
#
# This URI selects all the S1 products
#
# https://scihub.copernicus.eu/dhus/odata/v1/Products?**$filter=startswith(Name,'S1')**
#
#
# **Products archiving status:**
# - **true**
# - **false**
#
#
# If we wanted to see only entries newer than the first of February 2015 which are from the S1 product:

# %%
uri += "&$filter=IngestionDate gt datetime'2015-02-01T00:00:00.000'"
uri += " and startswith(Name,'S1')"

# %% [markdown]
# ## Orderby
#
# Order objects in ascending (asc) or descending order (desc).
#
# We will order by IngestionDate descending

# %%
uri += '&$orderby=IngestionDate desc'

# %% [markdown]
# ## Select
#
# Filter for a subset of properties to be returned, using a comma seperated list of selection clauses.
#
# Each selection clause may be a Property name, Navigation Property name, or the "*" character.
#
# We will only want the return value of Name CreationDate, ContentType and Id

# %%
uri+= '&$select=Id,Name,ContentType,ContentDate'

# %% [markdown]
# ## Skip and top
#
# top will select the first n entries, where n is an integer provided
#
# skip will skip the first n entries, where n is an integer provided

# %%
uri+= '&$skip=10'
uri += '&$top=100'

# %% [markdown]
# ## Count and inlinecount
#
# count allows to return a count of returned resources with the response
#
# inlinecount specifies the count of the number of entities to be included in the response

# %%
uri+= '&$inlinecount=allpages'

# %% [markdown]
# ## Expand
#
# To expand our results based on a specific Navigation Propery, we can write expand

# %%
uri += '&$expand=Nodes'

# %%
print(uri)
#To retrieve the data all we need to do is fill in our log in information, an account can be made on https://www.copernicus.eu/en
data = requests.get(uri, auth=(user, password))
#The Below will return the json decoded text, with .content you can get the raw text and with .text you can get the decoded content
print(data.text[:1000],'........')
#Takes ~3s per included result, However this output may not be useful
# Out:
# https://scihub.copernicus.eu/dhus/odata/v1/Products?$format=json&$filter=IngestionDate gt datetime'2015-02-01T00:00:00.000' and startswith(Name,'S1')&$orderby=IngestionDate desc&$select=Id,Name,ContentType,ContentDate&$skip=10&$top=100&$inlinecount=allpages
# {"d":{"__count":"7119955","results":[{"__metadata":{"id":"https://scihub.copernicus.eu/dhus/odata/v1/Products('a9f27546-2998-433b-9ca1-c17912987460')","uri":"https://scihub.copernicus.eu/dhus/odata/v1/Products('a9f27546-2998-433b-9ca1-c17912987460')","type":"DHuS.Product","content_type":"application/octet-stream","media_src":"https://scihub.copernicus.eu/dhus/odata/v1/Products('a9f27546-2998-433b-9ca1-c17912987460')/$value","edit_media":"https://scihub.copernicus.eu/dhus/odata/v1/Products('a9f27546-2998-433b-9ca1-c17912987460')/$value"},"Id":"a9f27546-2998-433b-9ca1-c17912987460","Name":"S1B_IW_GRDH_1SDV_20211005T032040_20211005T032105_028995_0375BC_75E3","ContentType":"application/octet-stream","ContentDate":{"__metadata":{"type":"DHuS.TimeRange"},"Start":"\/Date(1633404040010)\/","End":"\/Date(1633404065007)\/"}},{"__metadata":{"id":"https://scihub.copernicus.eu/dhus/odata/v1/Products('5f2a0932-f3dd-4c5d-a406-5c8d70bd642b')","uri":"https://scihub.copernicus.eu/dhus/odata/v1/Products( ........

# %%
# The first few keys here are
data.json()['d']['results']
# What we are left with is a list of different products

# If we now access the first entry, we have a choice of different parameters for this product
data.json()['d']['results'][0].keys()
# Out:
# dict_keys(['__metadata', 'Id', 'Name', 'ContentType', 'ContentDate'])

# %%
#To get one product
data.json()['d']['results'][8]
# Out:
# {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')",
#   'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')",
#   'type': 'DHuS.Product',
#   'content_type': 'application/octet-stream',
#   'media_src': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/$value",
#   'edit_media': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/$value"},
#  'Id': '659851c9-6b5e-483f-97aa-972c3823abe2',
#  'Name': 'S1B_IW_GRDH_1SDV_20211004T170346_20211004T170411_028988_037598_E3A6',
#  'ContentType': 'application/octet-stream',
#  'ContentDate': {'__metadata': {'type': 'DHuS.TimeRange'},
#   'Start': '/Date(1633367026553)/',
#   'End': '/Date(1633367051552)/'}}

# %% [markdown]
# ## Download
#
# We can download a full resource, it will be returned in xml format, if we know the products UUID or simply ID, we can get an outline of the xml schema of the node with:
#
# \<ServiceRootUri\>/Products('\<Id\>')/Nodes('[PRODUCT_NAME.SAFE]')/Nodes
#
# We can download the manifest file using:
#
# \<ServiceRootUri\>/Products('Id')/Nodes('Filename')/Nodes('manifest.safe')/$value
#
# And the quick look file:
#
# \<ServiceRootUri\>/Products('Id')/Nodes('Filename')/Nodes('preview')/Nodes('quick-look.png')/$value

# %%
# An example
uri = "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes"

first_level_nodes = requests.get(uri, auth=(user, password))

# %%
#Here we are retrieving an xml format, we can retrieve json by simply placing ?$format=json at the end of the querrry

from bs4 import BeautifulSoup

fln = BeautifulSoup(first_level_nodes.content, 'xml')

fln
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <feed xml:base="https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/" xmlns="http://www.w3.org/2005/Atom" xmlns:d="http://schemas.microsoft.com/ado/2007/08/dataservices" xmlns:m="http://schemas.microsoft.com/ado/2007/08/dataservices/metadata"><id>https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes</id><title type="text">Nodes</title><updated>2021-09-29T09:57:15.113Z</updated><author><name/></author><link href="Nodes" rel="self" title="Nodes"/><entry><id>https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')</id><title type="text">S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE</title><updated>2021-09-29T09:57:15.131Z</updated><category scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" term="DHuS.Node"/><link href="Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')" rel="edit" title="Node"/><link href="Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/$value" rel="edit-media" type="application/octet-stream"/><link href="Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes" rel="http://schemas.microsoft.com/ado/2007/08/dataservices/related/Nodes" title="Nodes" type="application/atom+xml;type=feed"/><link href="Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Attributes" rel="http://schemas.microsoft.com/ado/2007/08/dataservices/related/Attributes" title="Attributes" type="application/atom+xml;type=feed"/><link href="Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Class" rel="http://schemas.microsoft.com/ado/2007/08/dataservices/related/Class" title="Class" type="application/atom+xml;type=entry"/><content src="Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/$value" type="application/octet-stream"/><m:properties><d:Id>S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE</d:Id><d:Name>S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE</d:Name><d:ContentType>SENTINEL-1 Interferometric Wide Swath Level 0S Product - Dual polarization</d:ContentType><d:ContentLength>0</d:ContentLength><d:ChildrenNumber>9</d:ChildrenNumber><d:Value m:null="true"/></m:properties></entry></feed>

# %%
#To find specific things within this

fln.find_all('Id')
#This gives us the first NodeId, now we can get the xml_scheme
# Out:
# [<d:Id>S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE</d:Id>]

# %%
#Here we are using the json format again, as I find it easier to work with, here I also expanded on Nodes
uri = "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes?$format=json&$expand=Nodes"

xml_scheme = requests.get(uri, auth=(user, password))

xml_scheme.json()['d']['results'][0]
# Out:
# {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes('support')",
#   'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes('support')",
#   'type': 'DHuS.Node',
#   'content_type': 'application/octet-stream',
#   'media_src': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes('support')/$value",
#   'edit_media': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes('support')/$value"},
#  'Id': 'support',
#  'Name': 'support',
#  'ContentType': 'Item',
#  'ContentLength': '0',
#  'ChildrenNumber': '3',
#  'Value': None,
#  'Nodes': {'results': [{'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-annot.xsd')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-annot.xsd')",
#      'type': 'DHuS.Node',
#      'content_type': 'application/octet-stream',
#      'media_src': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-annot.xsd')/$value",
#      'edit_media': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-annot.xsd')/$value"},
#     'Id': 's1-level-0-annot.xsd',
#     'Name': 's1-level-0-annot.xsd',
#     'ContentType': 'XML Schema Document',
#     'ContentLength': '8074',
#     'ChildrenNumber': '1',
#     'Value': None,
#     'Nodes': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-annot.xsd')/Nodes"}},
#     'Attributes': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-annot.xsd')/Attributes"}},
#     'Class': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-annot.xsd')/Class"}}},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-index.xsd')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-index.xsd')",
#      'type': 'DHuS.Node',
#      'content_type': 'application/octet-stream',
#      'media_src': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-index.xsd')/$value",
#      'edit_media': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-index.xsd')/$value"},
#     'Id': 's1-level-0-index.xsd',
#     'Name': 's1-level-0-index.xsd',
#     'ContentType': 'XML Schema Document',
#     'ContentLength': '7125',
#     'ChildrenNumber': '1',
#     'Value': None,
#     'Nodes': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-index.xsd')/Nodes"}},
#     'Attributes': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-index.xsd')/Attributes"}},
#     'Class': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0-index.xsd')/Class"}}},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0.xsd')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0.xsd')",
#      'type': 'DHuS.Node',
#      'content_type': 'application/octet-stream',
#      'media_src': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0.xsd')/$value",
#      'edit_media': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0.xsd')/$value"},
#     'Id': 's1-level-0.xsd',
#     'Name': 's1-level-0.xsd',
#     'ContentType': 'XML Schema Document',
#     'ContentLength': '22995',
#     'ChildrenNumber': '1',
#     'Value': None,
#     'Nodes': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0.xsd')/Nodes"}},
#     'Attributes': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0.xsd')/Attributes"}},
#     'Class': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes/Nodes('s1-level-0.xsd')/Class"}}}]},
#  'Attributes': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes('support')/Attributes"}},
#  'Class': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes('support')/Class"}}}

# %%
# If we now want the manifest we would do:
        #If you figure out how to change the format of this querry please tell me
uri = "https://scihub.copernicus.eu/dhus/odata/v1/Products('263ace8d-680a-475e-88dc-b68e76d1159c')/Nodes('S1B_IW_RAW__0SDV_20210929T080443_20210929T080515_028910_037342_30C6.SAFE')/Nodes('manifest.safe')/$value"

manifest = requests.get(uri, auth=(user, password))


from bs4 import BeautifulSoup

mf = BeautifulSoup(manifest.content, 'xml')

mf.find_all()
# Out:
# [<xfdu:XFDU version="esa/safe/sentinel-1.0/sentinel-1/sar/level-0/standard/iwdp" xmlns:s1="http://www.esa.int/safe/sentinel-1.0/sentinel-1" xmlns:s1sar="http://www.esa.int/safe/sentinel-1.0/sentinel-1/sar" xmlns:xfdu="urn:ccsds:schema:xfdu:1">
#  <informationPackageMap>
#  <xfdu:contentUnit dmdID="acquisitionPeriod platform generalProductInformation" pdiID="processing" textInfo="Sentinel-1 Level 0 Package" unitType="SAFE Archive Information Package">
#  <xfdu:contentUnit repID="measurementAnnotationSchema" textInfo="Annotation for Measurement Data 1" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementAnnotData1"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit repID="measurementAnnotationSchema" textInfo="Annotation for Measurement Data 2" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementAnnotData2"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit dmdID="measurementOrbitReference measurementFrameSet measurementQualityInformation measurement1IndexAnnotation measurement1Annotation" repID="measurementSchema" textInfo="Measurement Data Unit 1" unitType="Measurement Data Unit">
#  <dataObjectPointer dataObjectID="measurementData1"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit dmdID="measurementOrbitReference measurementFrameSet measurementQualityInformation measurement2IndexAnnotation measurement2Annotation" repID="measurementSchema" textInfo="Measurement Data Unit 2" unitType="Measurement Data Unit">
#  <dataObjectPointer dataObjectID="measurementData2"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit repID="measurementIndexAnnotationSchema" textInfo="Index for Measurement Data 1" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementIndexData1"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit repID="measurementIndexAnnotationSchema" textInfo="Index for Measurement Data 2" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementIndexData2"/>
#  </xfdu:contentUnit>
#  </xfdu:contentUnit>
#  </informationPackageMap>
#  <metadataSection>
#  <metadataObject ID="acquisitionPeriod" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Acquisition Period" vocabularyName="SAFE">
#  <xmlData>
#  <acquisitionPeriod xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <startTime>2021-09-29T08:04:43.435249Z</startTime>
#  <stopTime>2021-09-29T08:05:15.834816Z</stopTime>
#  <extension>
#  <s1:timeANX>
#  <s1:startTimeANX>3285412.7070</s1:startTimeANX>
#  <s1:stopTimeANX>3317812.2740</s1:stopTimeANX>
#  </s1:timeANX>
#  </extension>
#  </acquisitionPeriod>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="platform" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Platform Description" vocabularyName="SAFE">
#  <xmlData>
#  <platform xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <nssdcIdentifier>2016-025A</nssdcIdentifier>
#  <familyName>SENTINEL-1</familyName>
#  <number>B</number>
#  <instrument>
#  <familyName abbreviation="SAR">Synthetic Aperture Radar</familyName>
#  <extension>
#  <s1sar:instrumentMode>
#  <s1sar:mode>IW</s1sar:mode>
#  </s1sar:instrumentMode>
#  </extension>
#  </instrument>
#  </platform>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="generalProductInformation" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="General Product Information" vocabularyName="SAFE">
#  <xmlData>
#  <standAloneProductInformation xmlns="http://www.esa.int/safe/sentinel-1.0/sentinel-1/sar">
#  <productClass>S</productClass>
#  <productClassDescription>SAR Slice L0 product</productClassDescription>
#  <productConsolidation>SLICE</productConsolidation>
#  <calISPPresent>TRUE</calISPPresent>
#  <noiseISPPresent>TRUE</noiseISPPresent>
#  <instrumentConfigurationID>2</instrumentConfigurationID>
#  <missionDataTakeID>226114</missionDataTakeID>
#  <circulationFlag>1</circulationFlag>
#  <sliceProductFlag>TRUE</sliceProductFlag>
#  <sliceNumber>1</sliceNumber>
#  <theoreticalSliceLength>25</theoreticalSliceLength>
#  <sliceOverlap>7.4</sliceOverlap>
#  <echoCompressionType>FDBAQ_0</echoCompressionType>
#  <noiseCompressionType>BAQ_5_BIT</noiseCompressionType>
#  <calCompressionType>BYPASS</calCompressionType>
#  <transmitterReceiverPolarisation dataObjectID="measurementData1">VH</transmitterReceiverPolarisation>
#  <transmitterReceiverPolarisation dataObjectID="measurementData2">VV</transmitterReceiverPolarisation>
#  <packetStoreID dataObjectID="measurementData1">21</packetStoreID>
#  <packetStoreID dataObjectID="measurementData2">22</packetStoreID>
#  <byteOrder dataObjectID="measurementData1">BIG_ENDIAN</byteOrder>
#  <byteOrder dataObjectID="measurementData2">BIG_ENDIAN</byteOrder>
#  <averageBitRate dataObjectID="measurementData1">223650636</averageBitRate>
#  <averageBitRate dataObjectID="measurementData2">188494951</averageBitRate>
#  </standAloneProductInformation>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="measurementOrbitReference" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Orbit Reference" vocabularyName="SAFE">
#  <xmlData>
#  <orbitReference xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <orbitNumber type="start">28910</orbitNumber>
#  <orbitNumber type="stop">28910</orbitNumber>
#  <relativeOrbitNumber type="start">9</relativeOrbitNumber>
#  <relativeOrbitNumber type="stop">9</relativeOrbitNumber>
#  <cycleNumber>172</cycleNumber>
#  <phaseIdentifier>1</phaseIdentifier>
#  <extension>
#  <s1:orbitProperties>
#  <s1:pass>DESCENDING</s1:pass>
#  <s1:ascendingNodeTime>2021-09-29T07:09:58.022569Z</s1:ascendingNodeTime>
#  </s1:orbitProperties>
#  </extension>
#  </orbitReference>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="processing" category="PDI" classification="PROVENANCE">
#  <metadataWrap mimeType="text/xml" textInfo="Processing" vocabularyName="SAFE">
#  <xmlData>
#  <processing name="Generation of Sentinel-1 L0 SAR Product, dual polarisation" start="2021-09-29T09:31:05.616464" stop="2021-09-29T09:31:05.742257" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <facility name="PAC1"/>
#  <resource name="S-1 Core PDGS S-1 Level-0 Product Format Specifications S1PD.SP.00110.ASTR" role="Applicable Document">
#  </resource>
#  <resource name="Sentinel-1 SAR Space Packet Protocol Data Unit S1-IF-ASD-PL-0007" role="Applicable Document" version="13.0">
#  </resource>
#  <resource name="Unknown" role="Raw Data">
#  <processing name="Generation of Sentinel-1 SAR Slice L0 product single polarisation" start="2021-09-29T09:30:11.253592" stop="2021-09-29T09:30:12.682501" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <resource name="S-1 Core PDGS S-1 Level-0 Product Format Specifications S1PD.SP.00110.ASTR" role="Applicable Document">
#  </resource>
#  <resource name="Sentinel-1 SAR Space Packet Protocol Data Unit S1-IF-ASD-PL-0007" role="Applicable Document" version="13.0">
#  </resource>
#  <resource name="Downlinked Stream" role="Raw Data">
#  <processing name="Raw Data Downlink Channel1 1" start="2021-09-29T09:09:40.570802" stop="2021-09-29T09:09:56.208138" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  </processing>
#  </resource>
#  </processing>
#  </resource>
#  <resource name="Unknown" role="Raw Data">
#  <processing name="Generation of Sentinel-1 SAR Slice L0 product single polarisation" start="2021-09-29T09:30:46.089571" stop="2021-09-29T09:30:47.396981" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <resource name="S-1 Core PDGS S-1 Level-0 Product Format Specifications S1PD.SP.00110.ASTR" role="Applicable Document">
#  </resource>
#  <resource name="Sentinel-1 SAR Space Packet Protocol Data Unit S1-IF-ASD-PL-0007" role="Applicable Document" version="13.0">
#  </resource>
#  <resource name="Downlinked Stream" role="Raw Data">
#  <processing name="Raw Data Downlink Channel2 2" start="2021-09-29T09:09:32.294042" stop="2021-09-29T09:09:51.235736" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  </processing>
#  </resource>
#  </processing>
#  </resource>
#  </processing>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="measurementFrameSet" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Frame Set" vocabularyName="SAFE">
#  <xmlData>
#  <frameSet xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <frame>
#  <footPrint srsName="http:/www.opengis.net/gml/srs/epsg.xml#4326">
#  <coordinates xmlns="http://www.opengis.net/gml">-18.8993,-39.6777 -20.8323,-40.2064 -21.2389,-37.8639 -19.2949,-37.3641 -18.8993,-39.6777</coordinates>
#  </footPrint>
#  </frame>
#  </frameSet>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="measurementQualityInformation" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Quality Information" vocabularyName="SAFE">
#  <xmlData>
#  <qualityInformation xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData1</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>
#  </qualityInformation>
#  <qualityInformation xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData2</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>
#  </qualityInformation>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="measurement1Annotation" category="DMD" classification="DESCRIPTION">
#  <dataObjectPointer dataObjectID="measurementAnnotData1"/>
#  </metadataObject>
#  <metadataObject ID="measurement1IndexAnnotation" category="DMD" classification="DESCRIPTION">
#  <dataObjectPointer dataObjectID="measurementIndexData1"/>
#  </metadataObject>
#  <metadataObject ID="measurement2Annotation" category="DMD" classification="DESCRIPTION">
#  <dataObjectPointer dataObjectID="measurementAnnotData2"/>
#  </metadataObject>
#  <metadataObject ID="measurement2IndexAnnotation" category="DMD" classification="DESCRIPTION">
#  <dataObjectPointer dataObjectID="measurementIndexData2"/>
#  </metadataObject>
#  <metadataObject ID="measurementAnnotationSchema" category="REP" classification="SYNTAX">
#  <metadataReference href="./support/s1-level-0-annot.xsd" locatorType="URL" mimeType="text/xml" vocabularyName="SDF"/>
#  </metadataObject>
#  <metadataObject ID="measurementIndexAnnotationSchema" category="REP" classification="SYNTAX">
#  <metadataReference href="./support/s1-level-0-index.xsd" locatorType="URL" mimeType="text/xml" vocabularyName="SDF"/>
#  </metadataObject>
#  <metadataObject ID="measurementSchema" category="REP" classification="SYNTAX">
#  <metadataReference href="./support/s1-level-0.xsd" locatorType="URL" mimeType="text/xml" vocabularyName="SDF"/>
#  </metadataObject>
#  </metadataSection>
#  <dataObjectSection>
#  <dataObject ID="measurementAnnotData1" repID="measurementAnnotationSchema">
#  <byteStream mimeType="application/octet-stream" size="1346358">
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342-annot.dat" locatorType="URL" textInfo="Annotation for Measurement Data"/>
#  <checksum checksumName="MD5">be2c6814fdaa857c60ef7b28ef44cdae</checksum>
#  </byteStream>
#  </dataObject>
#  <dataObject ID="measurementAnnotData2" repID="measurementAnnotationSchema">
#  <byteStream mimeType="application/octet-stream" size="1346358">
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342-annot.dat" locatorType="URL" textInfo="Annotation for Measurement Data"/>
#  <checksum checksumName="MD5">5aff5196c3ede79e18d5f0c85ebc7358</checksum>
#  </byteStream>
#  </dataObject>
#  <dataObject ID="measurementData1" repID="measurementSchema">
#  <byteStream mimeType="application/octet-stream" size="905772972">
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342.dat" locatorType="URL" textInfo="Measurement Data Unit"/>
#  <checksum checksumName="MD5">2302171fb8e314712e5232a28e5dbf0c</checksum>
#  </byteStream>
#  </dataObject>
#  <dataObject ID="measurementData2" repID="measurementSchema">
#  <byteStream mimeType="application/octet-stream" size="763394352">
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342.dat" locatorType="URL" textInfo="Measurement Data Unit"/>
#  <checksum checksumName="MD5">8ee5adec8e08d1d6373845b9ef263c69</checksum>
#  </byteStream>
#  </dataObject>
#  <dataObject ID="measurementIndexData1" repID="measurementIndexAnnotationSchema">
#  <byteStream mimeType="application/octet-stream" size="1908">
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342-index.dat" locatorType="URL" textInfo="Index for Measurement Data"/>
#  <checksum checksumName="MD5">83f038d8d91099ddbc9a6ae29e4b34ce</checksum>
#  </byteStream>
#  </dataObject>
#  <dataObject ID="measurementIndexData2" repID="measurementIndexAnnotationSchema">
#  <byteStream mimeType="application/octet-stream" size="1908">
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342-index.dat" locatorType="URL" textInfo="Index for Measurement Data"/>
#  <checksum checksumName="MD5">501dc9466888f8b5cadb1b77290134da</checksum>
#  </byteStream>
#  </dataObject>
#  </dataObjectSection>
#  </xfdu:XFDU>,
#  <informationPackageMap>
#  <xfdu:contentUnit dmdID="acquisitionPeriod platform generalProductInformation" pdiID="processing" textInfo="Sentinel-1 Level 0 Package" unitType="SAFE Archive Information Package">
#  <xfdu:contentUnit repID="measurementAnnotationSchema" textInfo="Annotation for Measurement Data 1" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementAnnotData1"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit repID="measurementAnnotationSchema" textInfo="Annotation for Measurement Data 2" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementAnnotData2"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit dmdID="measurementOrbitReference measurementFrameSet measurementQualityInformation measurement1IndexAnnotation measurement1Annotation" repID="measurementSchema" textInfo="Measurement Data Unit 1" unitType="Measurement Data Unit">
#  <dataObjectPointer dataObjectID="measurementData1"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit dmdID="measurementOrbitReference measurementFrameSet measurementQualityInformation measurement2IndexAnnotation measurement2Annotation" repID="measurementSchema" textInfo="Measurement Data Unit 2" unitType="Measurement Data Unit">
#  <dataObjectPointer dataObjectID="measurementData2"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit repID="measurementIndexAnnotationSchema" textInfo="Index for Measurement Data 1" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementIndexData1"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit repID="measurementIndexAnnotationSchema" textInfo="Index for Measurement Data 2" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementIndexData2"/>
#  </xfdu:contentUnit>
#  </xfdu:contentUnit>
#  </informationPackageMap>,
#  <xfdu:contentUnit dmdID="acquisitionPeriod platform generalProductInformation" pdiID="processing" textInfo="Sentinel-1 Level 0 Package" unitType="SAFE Archive Information Package">
#  <xfdu:contentUnit repID="measurementAnnotationSchema" textInfo="Annotation for Measurement Data 1" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementAnnotData1"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit repID="measurementAnnotationSchema" textInfo="Annotation for Measurement Data 2" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementAnnotData2"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit dmdID="measurementOrbitReference measurementFrameSet measurementQualityInformation measurement1IndexAnnotation measurement1Annotation" repID="measurementSchema" textInfo="Measurement Data Unit 1" unitType="Measurement Data Unit">
#  <dataObjectPointer dataObjectID="measurementData1"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit dmdID="measurementOrbitReference measurementFrameSet measurementQualityInformation measurement2IndexAnnotation measurement2Annotation" repID="measurementSchema" textInfo="Measurement Data Unit 2" unitType="Measurement Data Unit">
#  <dataObjectPointer dataObjectID="measurementData2"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit repID="measurementIndexAnnotationSchema" textInfo="Index for Measurement Data 1" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementIndexData1"/>
#  </xfdu:contentUnit>
#  <xfdu:contentUnit repID="measurementIndexAnnotationSchema" textInfo="Index for Measurement Data 2" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementIndexData2"/>
#  </xfdu:contentUnit>
#  </xfdu:contentUnit>,
#  <xfdu:contentUnit repID="measurementAnnotationSchema" textInfo="Annotation for Measurement Data 1" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementAnnotData1"/>
#  </xfdu:contentUnit>,
#  <dataObjectPointer dataObjectID="measurementAnnotData1"/>,
#  <xfdu:contentUnit repID="measurementAnnotationSchema" textInfo="Annotation for Measurement Data 2" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementAnnotData2"/>
#  </xfdu:contentUnit>,
#  <dataObjectPointer dataObjectID="measurementAnnotData2"/>,
#  <xfdu:contentUnit dmdID="measurementOrbitReference measurementFrameSet measurementQualityInformation measurement1IndexAnnotation measurement1Annotation" repID="measurementSchema" textInfo="Measurement Data Unit 1" unitType="Measurement Data Unit">
#  <dataObjectPointer dataObjectID="measurementData1"/>
#  </xfdu:contentUnit>,
#  <dataObjectPointer dataObjectID="measurementData1"/>,
#  <xfdu:contentUnit dmdID="measurementOrbitReference measurementFrameSet measurementQualityInformation measurement2IndexAnnotation measurement2Annotation" repID="measurementSchema" textInfo="Measurement Data Unit 2" unitType="Measurement Data Unit">
#  <dataObjectPointer dataObjectID="measurementData2"/>
#  </xfdu:contentUnit>,
#  <dataObjectPointer dataObjectID="measurementData2"/>,
#  <xfdu:contentUnit repID="measurementIndexAnnotationSchema" textInfo="Index for Measurement Data 1" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementIndexData1"/>
#  </xfdu:contentUnit>,
#  <dataObjectPointer dataObjectID="measurementIndexData1"/>,
#  <xfdu:contentUnit repID="measurementIndexAnnotationSchema" textInfo="Index for Measurement Data 2" unitType="Metadata Unit">
#  <dataObjectPointer dataObjectID="measurementIndexData2"/>
#  </xfdu:contentUnit>,
#  <dataObjectPointer dataObjectID="measurementIndexData2"/>,
#  <metadataSection>
#  <metadataObject ID="acquisitionPeriod" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Acquisition Period" vocabularyName="SAFE">
#  <xmlData>
#  <acquisitionPeriod xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <startTime>2021-09-29T08:04:43.435249Z</startTime>
#  <stopTime>2021-09-29T08:05:15.834816Z</stopTime>
#  <extension>
#  <s1:timeANX>
#  <s1:startTimeANX>3285412.7070</s1:startTimeANX>
#  <s1:stopTimeANX>3317812.2740</s1:stopTimeANX>
#  </s1:timeANX>
#  </extension>
#  </acquisitionPeriod>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="platform" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Platform Description" vocabularyName="SAFE">
#  <xmlData>
#  <platform xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <nssdcIdentifier>2016-025A</nssdcIdentifier>
#  <familyName>SENTINEL-1</familyName>
#  <number>B</number>
#  <instrument>
#  <familyName abbreviation="SAR">Synthetic Aperture Radar</familyName>
#  <extension>
#  <s1sar:instrumentMode>
#  <s1sar:mode>IW</s1sar:mode>
#  </s1sar:instrumentMode>
#  </extension>
#  </instrument>
#  </platform>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="generalProductInformation" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="General Product Information" vocabularyName="SAFE">
#  <xmlData>
#  <standAloneProductInformation xmlns="http://www.esa.int/safe/sentinel-1.0/sentinel-1/sar">
#  <productClass>S</productClass>
#  <productClassDescription>SAR Slice L0 product</productClassDescription>
#  <productConsolidation>SLICE</productConsolidation>
#  <calISPPresent>TRUE</calISPPresent>
#  <noiseISPPresent>TRUE</noiseISPPresent>
#  <instrumentConfigurationID>2</instrumentConfigurationID>
#  <missionDataTakeID>226114</missionDataTakeID>
#  <circulationFlag>1</circulationFlag>
#  <sliceProductFlag>TRUE</sliceProductFlag>
#  <sliceNumber>1</sliceNumber>
#  <theoreticalSliceLength>25</theoreticalSliceLength>
#  <sliceOverlap>7.4</sliceOverlap>
#  <echoCompressionType>FDBAQ_0</echoCompressionType>
#  <noiseCompressionType>BAQ_5_BIT</noiseCompressionType>
#  <calCompressionType>BYPASS</calCompressionType>
#  <transmitterReceiverPolarisation dataObjectID="measurementData1">VH</transmitterReceiverPolarisation>
#  <transmitterReceiverPolarisation dataObjectID="measurementData2">VV</transmitterReceiverPolarisation>
#  <packetStoreID dataObjectID="measurementData1">21</packetStoreID>
#  <packetStoreID dataObjectID="measurementData2">22</packetStoreID>
#  <byteOrder dataObjectID="measurementData1">BIG_ENDIAN</byteOrder>
#  <byteOrder dataObjectID="measurementData2">BIG_ENDIAN</byteOrder>
#  <averageBitRate dataObjectID="measurementData1">223650636</averageBitRate>
#  <averageBitRate dataObjectID="measurementData2">188494951</averageBitRate>
#  </standAloneProductInformation>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="measurementOrbitReference" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Orbit Reference" vocabularyName="SAFE">
#  <xmlData>
#  <orbitReference xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <orbitNumber type="start">28910</orbitNumber>
#  <orbitNumber type="stop">28910</orbitNumber>
#  <relativeOrbitNumber type="start">9</relativeOrbitNumber>
#  <relativeOrbitNumber type="stop">9</relativeOrbitNumber>
#  <cycleNumber>172</cycleNumber>
#  <phaseIdentifier>1</phaseIdentifier>
#  <extension>
#  <s1:orbitProperties>
#  <s1:pass>DESCENDING</s1:pass>
#  <s1:ascendingNodeTime>2021-09-29T07:09:58.022569Z</s1:ascendingNodeTime>
#  </s1:orbitProperties>
#  </extension>
#  </orbitReference>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="processing" category="PDI" classification="PROVENANCE">
#  <metadataWrap mimeType="text/xml" textInfo="Processing" vocabularyName="SAFE">
#  <xmlData>
#  <processing name="Generation of Sentinel-1 L0 SAR Product, dual polarisation" start="2021-09-29T09:31:05.616464" stop="2021-09-29T09:31:05.742257" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <facility name="PAC1"/>
#  <resource name="S-1 Core PDGS S-1 Level-0 Product Format Specifications S1PD.SP.00110.ASTR" role="Applicable Document">
#  </resource>
#  <resource name="Sentinel-1 SAR Space Packet Protocol Data Unit S1-IF-ASD-PL-0007" role="Applicable Document" version="13.0">
#  </resource>
#  <resource name="Unknown" role="Raw Data">
#  <processing name="Generation of Sentinel-1 SAR Slice L0 product single polarisation" start="2021-09-29T09:30:11.253592" stop="2021-09-29T09:30:12.682501" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <resource name="S-1 Core PDGS S-1 Level-0 Product Format Specifications S1PD.SP.00110.ASTR" role="Applicable Document">
#  </resource>
#  <resource name="Sentinel-1 SAR Space Packet Protocol Data Unit S1-IF-ASD-PL-0007" role="Applicable Document" version="13.0">
#  </resource>
#  <resource name="Downlinked Stream" role="Raw Data">
#  <processing name="Raw Data Downlink Channel1 1" start="2021-09-29T09:09:40.570802" stop="2021-09-29T09:09:56.208138" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  </processing>
#  </resource>
#  </processing>
#  </resource>
#  <resource name="Unknown" role="Raw Data">
#  <processing name="Generation of Sentinel-1 SAR Slice L0 product single polarisation" start="2021-09-29T09:30:46.089571" stop="2021-09-29T09:30:47.396981" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <resource name="S-1 Core PDGS S-1 Level-0 Product Format Specifications S1PD.SP.00110.ASTR" role="Applicable Document">
#  </resource>
#  <resource name="Sentinel-1 SAR Space Packet Protocol Data Unit S1-IF-ASD-PL-0007" role="Applicable Document" version="13.0">
#  </resource>
#  <resource name="Downlinked Stream" role="Raw Data">
#  <processing name="Raw Data Downlink Channel2 2" start="2021-09-29T09:09:32.294042" stop="2021-09-29T09:09:51.235736" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  </processing>
#  </resource>
#  </processing>
#  </resource>
#  </processing>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="measurementFrameSet" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Frame Set" vocabularyName="SAFE">
#  <xmlData>
#  <frameSet xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <frame>
#  <footPrint srsName="http:/www.opengis.net/gml/srs/epsg.xml#4326">
#  <coordinates xmlns="http://www.opengis.net/gml">-18.8993,-39.6777 -20.8323,-40.2064 -21.2389,-37.8639 -19.2949,-37.3641 -18.8993,-39.6777</coordinates>
#  </footPrint>
#  </frame>
#  </frameSet>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="measurementQualityInformation" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Quality Information" vocabularyName="SAFE">
#  <xmlData>
#  <qualityInformation xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData1</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>
#  </qualityInformation>
#  <qualityInformation xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData2</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>
#  </qualityInformation>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>
#  <metadataObject ID="measurement1Annotation" category="DMD" classification="DESCRIPTION">
#  <dataObjectPointer dataObjectID="measurementAnnotData1"/>
#  </metadataObject>
#  <metadataObject ID="measurement1IndexAnnotation" category="DMD" classification="DESCRIPTION">
#  <dataObjectPointer dataObjectID="measurementIndexData1"/>
#  </metadataObject>
#  <metadataObject ID="measurement2Annotation" category="DMD" classification="DESCRIPTION">
#  <dataObjectPointer dataObjectID="measurementAnnotData2"/>
#  </metadataObject>
#  <metadataObject ID="measurement2IndexAnnotation" category="DMD" classification="DESCRIPTION">
#  <dataObjectPointer dataObjectID="measurementIndexData2"/>
#  </metadataObject>
#  <metadataObject ID="measurementAnnotationSchema" category="REP" classification="SYNTAX">
#  <metadataReference href="./support/s1-level-0-annot.xsd" locatorType="URL" mimeType="text/xml" vocabularyName="SDF"/>
#  </metadataObject>
#  <metadataObject ID="measurementIndexAnnotationSchema" category="REP" classification="SYNTAX">
#  <metadataReference href="./support/s1-level-0-index.xsd" locatorType="URL" mimeType="text/xml" vocabularyName="SDF"/>
#  </metadataObject>
#  <metadataObject ID="measurementSchema" category="REP" classification="SYNTAX">
#  <metadataReference href="./support/s1-level-0.xsd" locatorType="URL" mimeType="text/xml" vocabularyName="SDF"/>
#  </metadataObject>
#  </metadataSection>,
#  <metadataObject ID="acquisitionPeriod" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Acquisition Period" vocabularyName="SAFE">
#  <xmlData>
#  <acquisitionPeriod xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <startTime>2021-09-29T08:04:43.435249Z</startTime>
#  <stopTime>2021-09-29T08:05:15.834816Z</stopTime>
#  <extension>
#  <s1:timeANX>
#  <s1:startTimeANX>3285412.7070</s1:startTimeANX>
#  <s1:stopTimeANX>3317812.2740</s1:stopTimeANX>
#  </s1:timeANX>
#  </extension>
#  </acquisitionPeriod>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>,
#  <metadataWrap mimeType="text/xml" textInfo="Acquisition Period" vocabularyName="SAFE">
#  <xmlData>
#  <acquisitionPeriod xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <startTime>2021-09-29T08:04:43.435249Z</startTime>
#  <stopTime>2021-09-29T08:05:15.834816Z</stopTime>
#  <extension>
#  <s1:timeANX>
#  <s1:startTimeANX>3285412.7070</s1:startTimeANX>
#  <s1:stopTimeANX>3317812.2740</s1:stopTimeANX>
#  </s1:timeANX>
#  </extension>
#  </acquisitionPeriod>
#  </xmlData>
#  </metadataWrap>,
#  <xmlData>
#  <acquisitionPeriod xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <startTime>2021-09-29T08:04:43.435249Z</startTime>
#  <stopTime>2021-09-29T08:05:15.834816Z</stopTime>
#  <extension>
#  <s1:timeANX>
#  <s1:startTimeANX>3285412.7070</s1:startTimeANX>
#  <s1:stopTimeANX>3317812.2740</s1:stopTimeANX>
#  </s1:timeANX>
#  </extension>
#  </acquisitionPeriod>
#  </xmlData>,
#  <acquisitionPeriod xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <startTime>2021-09-29T08:04:43.435249Z</startTime>
#  <stopTime>2021-09-29T08:05:15.834816Z</stopTime>
#  <extension>
#  <s1:timeANX>
#  <s1:startTimeANX>3285412.7070</s1:startTimeANX>
#  <s1:stopTimeANX>3317812.2740</s1:stopTimeANX>
#  </s1:timeANX>
#  </extension>
#  </acquisitionPeriod>,
#  <startTime>2021-09-29T08:04:43.435249Z</startTime>,
#  <stopTime>2021-09-29T08:05:15.834816Z</stopTime>,
#  <extension>
#  <s1:timeANX>
#  <s1:startTimeANX>3285412.7070</s1:startTimeANX>
#  <s1:stopTimeANX>3317812.2740</s1:stopTimeANX>
#  </s1:timeANX>
#  </extension>,
#  <s1:timeANX>
#  <s1:startTimeANX>3285412.7070</s1:startTimeANX>
#  <s1:stopTimeANX>3317812.2740</s1:stopTimeANX>
#  </s1:timeANX>,
#  <s1:startTimeANX>3285412.7070</s1:startTimeANX>,
#  <s1:stopTimeANX>3317812.2740</s1:stopTimeANX>,
#  <metadataObject ID="platform" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Platform Description" vocabularyName="SAFE">
#  <xmlData>
#  <platform xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <nssdcIdentifier>2016-025A</nssdcIdentifier>
#  <familyName>SENTINEL-1</familyName>
#  <number>B</number>
#  <instrument>
#  <familyName abbreviation="SAR">Synthetic Aperture Radar</familyName>
#  <extension>
#  <s1sar:instrumentMode>
#  <s1sar:mode>IW</s1sar:mode>
#  </s1sar:instrumentMode>
#  </extension>
#  </instrument>
#  </platform>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>,
#  <metadataWrap mimeType="text/xml" textInfo="Platform Description" vocabularyName="SAFE">
#  <xmlData>
#  <platform xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <nssdcIdentifier>2016-025A</nssdcIdentifier>
#  <familyName>SENTINEL-1</familyName>
#  <number>B</number>
#  <instrument>
#  <familyName abbreviation="SAR">Synthetic Aperture Radar</familyName>
#  <extension>
#  <s1sar:instrumentMode>
#  <s1sar:mode>IW</s1sar:mode>
#  </s1sar:instrumentMode>
#  </extension>
#  </instrument>
#  </platform>
#  </xmlData>
#  </metadataWrap>,
#  <xmlData>
#  <platform xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <nssdcIdentifier>2016-025A</nssdcIdentifier>
#  <familyName>SENTINEL-1</familyName>
#  <number>B</number>
#  <instrument>
#  <familyName abbreviation="SAR">Synthetic Aperture Radar</familyName>
#  <extension>
#  <s1sar:instrumentMode>
#  <s1sar:mode>IW</s1sar:mode>
#  </s1sar:instrumentMode>
#  </extension>
#  </instrument>
#  </platform>
#  </xmlData>,
#  <platform xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <nssdcIdentifier>2016-025A</nssdcIdentifier>
#  <familyName>SENTINEL-1</familyName>
#  <number>B</number>
#  <instrument>
#  <familyName abbreviation="SAR">Synthetic Aperture Radar</familyName>
#  <extension>
#  <s1sar:instrumentMode>
#  <s1sar:mode>IW</s1sar:mode>
#  </s1sar:instrumentMode>
#  </extension>
#  </instrument>
#  </platform>,
#  <nssdcIdentifier>2016-025A</nssdcIdentifier>,
#  <familyName>SENTINEL-1</familyName>,
#  <number>B</number>,
#  <instrument>
#  <familyName abbreviation="SAR">Synthetic Aperture Radar</familyName>
#  <extension>
#  <s1sar:instrumentMode>
#  <s1sar:mode>IW</s1sar:mode>
#  </s1sar:instrumentMode>
#  </extension>
#  </instrument>,
#  <familyName abbreviation="SAR">Synthetic Aperture Radar</familyName>,
#  <extension>
#  <s1sar:instrumentMode>
#  <s1sar:mode>IW</s1sar:mode>
#  </s1sar:instrumentMode>
#  </extension>,
#  <s1sar:instrumentMode>
#  <s1sar:mode>IW</s1sar:mode>
#  </s1sar:instrumentMode>,
#  <s1sar:mode>IW</s1sar:mode>,
#  <metadataObject ID="generalProductInformation" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="General Product Information" vocabularyName="SAFE">
#  <xmlData>
#  <standAloneProductInformation xmlns="http://www.esa.int/safe/sentinel-1.0/sentinel-1/sar">
#  <productClass>S</productClass>
#  <productClassDescription>SAR Slice L0 product</productClassDescription>
#  <productConsolidation>SLICE</productConsolidation>
#  <calISPPresent>TRUE</calISPPresent>
#  <noiseISPPresent>TRUE</noiseISPPresent>
#  <instrumentConfigurationID>2</instrumentConfigurationID>
#  <missionDataTakeID>226114</missionDataTakeID>
#  <circulationFlag>1</circulationFlag>
#  <sliceProductFlag>TRUE</sliceProductFlag>
#  <sliceNumber>1</sliceNumber>
#  <theoreticalSliceLength>25</theoreticalSliceLength>
#  <sliceOverlap>7.4</sliceOverlap>
#  <echoCompressionType>FDBAQ_0</echoCompressionType>
#  <noiseCompressionType>BAQ_5_BIT</noiseCompressionType>
#  <calCompressionType>BYPASS</calCompressionType>
#  <transmitterReceiverPolarisation dataObjectID="measurementData1">VH</transmitterReceiverPolarisation>
#  <transmitterReceiverPolarisation dataObjectID="measurementData2">VV</transmitterReceiverPolarisation>
#  <packetStoreID dataObjectID="measurementData1">21</packetStoreID>
#  <packetStoreID dataObjectID="measurementData2">22</packetStoreID>
#  <byteOrder dataObjectID="measurementData1">BIG_ENDIAN</byteOrder>
#  <byteOrder dataObjectID="measurementData2">BIG_ENDIAN</byteOrder>
#  <averageBitRate dataObjectID="measurementData1">223650636</averageBitRate>
#  <averageBitRate dataObjectID="measurementData2">188494951</averageBitRate>
#  </standAloneProductInformation>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>,
#  <metadataWrap mimeType="text/xml" textInfo="General Product Information" vocabularyName="SAFE">
#  <xmlData>
#  <standAloneProductInformation xmlns="http://www.esa.int/safe/sentinel-1.0/sentinel-1/sar">
#  <productClass>S</productClass>
#  <productClassDescription>SAR Slice L0 product</productClassDescription>
#  <productConsolidation>SLICE</productConsolidation>
#  <calISPPresent>TRUE</calISPPresent>
#  <noiseISPPresent>TRUE</noiseISPPresent>
#  <instrumentConfigurationID>2</instrumentConfigurationID>
#  <missionDataTakeID>226114</missionDataTakeID>
#  <circulationFlag>1</circulationFlag>
#  <sliceProductFlag>TRUE</sliceProductFlag>
#  <sliceNumber>1</sliceNumber>
#  <theoreticalSliceLength>25</theoreticalSliceLength>
#  <sliceOverlap>7.4</sliceOverlap>
#  <echoCompressionType>FDBAQ_0</echoCompressionType>
#  <noiseCompressionType>BAQ_5_BIT</noiseCompressionType>
#  <calCompressionType>BYPASS</calCompressionType>
#  <transmitterReceiverPolarisation dataObjectID="measurementData1">VH</transmitterReceiverPolarisation>
#  <transmitterReceiverPolarisation dataObjectID="measurementData2">VV</transmitterReceiverPolarisation>
#  <packetStoreID dataObjectID="measurementData1">21</packetStoreID>
#  <packetStoreID dataObjectID="measurementData2">22</packetStoreID>
#  <byteOrder dataObjectID="measurementData1">BIG_ENDIAN</byteOrder>
#  <byteOrder dataObjectID="measurementData2">BIG_ENDIAN</byteOrder>
#  <averageBitRate dataObjectID="measurementData1">223650636</averageBitRate>
#  <averageBitRate dataObjectID="measurementData2">188494951</averageBitRate>
#  </standAloneProductInformation>
#  </xmlData>
#  </metadataWrap>,
#  <xmlData>
#  <standAloneProductInformation xmlns="http://www.esa.int/safe/sentinel-1.0/sentinel-1/sar">
#  <productClass>S</productClass>
#  <productClassDescription>SAR Slice L0 product</productClassDescription>
#  <productConsolidation>SLICE</productConsolidation>
#  <calISPPresent>TRUE</calISPPresent>
#  <noiseISPPresent>TRUE</noiseISPPresent>
#  <instrumentConfigurationID>2</instrumentConfigurationID>
#  <missionDataTakeID>226114</missionDataTakeID>
#  <circulationFlag>1</circulationFlag>
#  <sliceProductFlag>TRUE</sliceProductFlag>
#  <sliceNumber>1</sliceNumber>
#  <theoreticalSliceLength>25</theoreticalSliceLength>
#  <sliceOverlap>7.4</sliceOverlap>
#  <echoCompressionType>FDBAQ_0</echoCompressionType>
#  <noiseCompressionType>BAQ_5_BIT</noiseCompressionType>
#  <calCompressionType>BYPASS</calCompressionType>
#  <transmitterReceiverPolarisation dataObjectID="measurementData1">VH</transmitterReceiverPolarisation>
#  <transmitterReceiverPolarisation dataObjectID="measurementData2">VV</transmitterReceiverPolarisation>
#  <packetStoreID dataObjectID="measurementData1">21</packetStoreID>
#  <packetStoreID dataObjectID="measurementData2">22</packetStoreID>
#  <byteOrder dataObjectID="measurementData1">BIG_ENDIAN</byteOrder>
#  <byteOrder dataObjectID="measurementData2">BIG_ENDIAN</byteOrder>
#  <averageBitRate dataObjectID="measurementData1">223650636</averageBitRate>
#  <averageBitRate dataObjectID="measurementData2">188494951</averageBitRate>
#  </standAloneProductInformation>
#  </xmlData>,
#  <standAloneProductInformation xmlns="http://www.esa.int/safe/sentinel-1.0/sentinel-1/sar">
#  <productClass>S</productClass>
#  <productClassDescription>SAR Slice L0 product</productClassDescription>
#  <productConsolidation>SLICE</productConsolidation>
#  <calISPPresent>TRUE</calISPPresent>
#  <noiseISPPresent>TRUE</noiseISPPresent>
#  <instrumentConfigurationID>2</instrumentConfigurationID>
#  <missionDataTakeID>226114</missionDataTakeID>
#  <circulationFlag>1</circulationFlag>
#  <sliceProductFlag>TRUE</sliceProductFlag>
#  <sliceNumber>1</sliceNumber>
#  <theoreticalSliceLength>25</theoreticalSliceLength>
#  <sliceOverlap>7.4</sliceOverlap>
#  <echoCompressionType>FDBAQ_0</echoCompressionType>
#  <noiseCompressionType>BAQ_5_BIT</noiseCompressionType>
#  <calCompressionType>BYPASS</calCompressionType>
#  <transmitterReceiverPolarisation dataObjectID="measurementData1">VH</transmitterReceiverPolarisation>
#  <transmitterReceiverPolarisation dataObjectID="measurementData2">VV</transmitterReceiverPolarisation>
#  <packetStoreID dataObjectID="measurementData1">21</packetStoreID>
#  <packetStoreID dataObjectID="measurementData2">22</packetStoreID>
#  <byteOrder dataObjectID="measurementData1">BIG_ENDIAN</byteOrder>
#  <byteOrder dataObjectID="measurementData2">BIG_ENDIAN</byteOrder>
#  <averageBitRate dataObjectID="measurementData1">223650636</averageBitRate>
#  <averageBitRate dataObjectID="measurementData2">188494951</averageBitRate>
#  </standAloneProductInformation>,
#  <productClass>S</productClass>,
#  <productClassDescription>SAR Slice L0 product</productClassDescription>,
#  <productConsolidation>SLICE</productConsolidation>,
#  <calISPPresent>TRUE</calISPPresent>,
#  <noiseISPPresent>TRUE</noiseISPPresent>,
#  <instrumentConfigurationID>2</instrumentConfigurationID>,
#  <missionDataTakeID>226114</missionDataTakeID>,
#  <circulationFlag>1</circulationFlag>,
#  <sliceProductFlag>TRUE</sliceProductFlag>,
#  <sliceNumber>1</sliceNumber>,
#  <theoreticalSliceLength>25</theoreticalSliceLength>,
#  <sliceOverlap>7.4</sliceOverlap>,
#  <echoCompressionType>FDBAQ_0</echoCompressionType>,
#  <noiseCompressionType>BAQ_5_BIT</noiseCompressionType>,
#  <calCompressionType>BYPASS</calCompressionType>,
#  <transmitterReceiverPolarisation dataObjectID="measurementData1">VH</transmitterReceiverPolarisation>,
#  <transmitterReceiverPolarisation dataObjectID="measurementData2">VV</transmitterReceiverPolarisation>,
#  <packetStoreID dataObjectID="measurementData1">21</packetStoreID>,
#  <packetStoreID dataObjectID="measurementData2">22</packetStoreID>,
#  <byteOrder dataObjectID="measurementData1">BIG_ENDIAN</byteOrder>,
#  <byteOrder dataObjectID="measurementData2">BIG_ENDIAN</byteOrder>,
#  <averageBitRate dataObjectID="measurementData1">223650636</averageBitRate>,
#  <averageBitRate dataObjectID="measurementData2">188494951</averageBitRate>,
#  <metadataObject ID="measurementOrbitReference" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Orbit Reference" vocabularyName="SAFE">
#  <xmlData>
#  <orbitReference xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <orbitNumber type="start">28910</orbitNumber>
#  <orbitNumber type="stop">28910</orbitNumber>
#  <relativeOrbitNumber type="start">9</relativeOrbitNumber>
#  <relativeOrbitNumber type="stop">9</relativeOrbitNumber>
#  <cycleNumber>172</cycleNumber>
#  <phaseIdentifier>1</phaseIdentifier>
#  <extension>
#  <s1:orbitProperties>
#  <s1:pass>DESCENDING</s1:pass>
#  <s1:ascendingNodeTime>2021-09-29T07:09:58.022569Z</s1:ascendingNodeTime>
#  </s1:orbitProperties>
#  </extension>
#  </orbitReference>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>,
#  <metadataWrap mimeType="text/xml" textInfo="Orbit Reference" vocabularyName="SAFE">
#  <xmlData>
#  <orbitReference xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <orbitNumber type="start">28910</orbitNumber>
#  <orbitNumber type="stop">28910</orbitNumber>
#  <relativeOrbitNumber type="start">9</relativeOrbitNumber>
#  <relativeOrbitNumber type="stop">9</relativeOrbitNumber>
#  <cycleNumber>172</cycleNumber>
#  <phaseIdentifier>1</phaseIdentifier>
#  <extension>
#  <s1:orbitProperties>
#  <s1:pass>DESCENDING</s1:pass>
#  <s1:ascendingNodeTime>2021-09-29T07:09:58.022569Z</s1:ascendingNodeTime>
#  </s1:orbitProperties>
#  </extension>
#  </orbitReference>
#  </xmlData>
#  </metadataWrap>,
#  <xmlData>
#  <orbitReference xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <orbitNumber type="start">28910</orbitNumber>
#  <orbitNumber type="stop">28910</orbitNumber>
#  <relativeOrbitNumber type="start">9</relativeOrbitNumber>
#  <relativeOrbitNumber type="stop">9</relativeOrbitNumber>
#  <cycleNumber>172</cycleNumber>
#  <phaseIdentifier>1</phaseIdentifier>
#  <extension>
#  <s1:orbitProperties>
#  <s1:pass>DESCENDING</s1:pass>
#  <s1:ascendingNodeTime>2021-09-29T07:09:58.022569Z</s1:ascendingNodeTime>
#  </s1:orbitProperties>
#  </extension>
#  </orbitReference>
#  </xmlData>,
#  <orbitReference xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <orbitNumber type="start">28910</orbitNumber>
#  <orbitNumber type="stop">28910</orbitNumber>
#  <relativeOrbitNumber type="start">9</relativeOrbitNumber>
#  <relativeOrbitNumber type="stop">9</relativeOrbitNumber>
#  <cycleNumber>172</cycleNumber>
#  <phaseIdentifier>1</phaseIdentifier>
#  <extension>
#  <s1:orbitProperties>
#  <s1:pass>DESCENDING</s1:pass>
#  <s1:ascendingNodeTime>2021-09-29T07:09:58.022569Z</s1:ascendingNodeTime>
#  </s1:orbitProperties>
#  </extension>
#  </orbitReference>,
#  <orbitNumber type="start">28910</orbitNumber>,
#  <orbitNumber type="stop">28910</orbitNumber>,
#  <relativeOrbitNumber type="start">9</relativeOrbitNumber>,
#  <relativeOrbitNumber type="stop">9</relativeOrbitNumber>,
#  <cycleNumber>172</cycleNumber>,
#  <phaseIdentifier>1</phaseIdentifier>,
#  <extension>
#  <s1:orbitProperties>
#  <s1:pass>DESCENDING</s1:pass>
#  <s1:ascendingNodeTime>2021-09-29T07:09:58.022569Z</s1:ascendingNodeTime>
#  </s1:orbitProperties>
#  </extension>,
#  <s1:orbitProperties>
#  <s1:pass>DESCENDING</s1:pass>
#  <s1:ascendingNodeTime>2021-09-29T07:09:58.022569Z</s1:ascendingNodeTime>
#  </s1:orbitProperties>,
#  <s1:pass>DESCENDING</s1:pass>,
#  <s1:ascendingNodeTime>2021-09-29T07:09:58.022569Z</s1:ascendingNodeTime>,
#  <metadataObject ID="processing" category="PDI" classification="PROVENANCE">
#  <metadataWrap mimeType="text/xml" textInfo="Processing" vocabularyName="SAFE">
#  <xmlData>
#  <processing name="Generation of Sentinel-1 L0 SAR Product, dual polarisation" start="2021-09-29T09:31:05.616464" stop="2021-09-29T09:31:05.742257" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <facility name="PAC1"/>
#  <resource name="S-1 Core PDGS S-1 Level-0 Product Format Specifications S1PD.SP.00110.ASTR" role="Applicable Document">
#  </resource>
#  <resource name="Sentinel-1 SAR Space Packet Protocol Data Unit S1-IF-ASD-PL-0007" role="Applicable Document" version="13.0">
#  </resource>
#  <resource name="Unknown" role="Raw Data">
#  <processing name="Generation of Sentinel-1 SAR Slice L0 product single polarisation" start="2021-09-29T09:30:11.253592" stop="2021-09-29T09:30:12.682501" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <resource name="S-1 Core PDGS S-1 Level-0 Product Format Specifications S1PD.SP.00110.ASTR" role="Applicable Document">
#  </resource>
#  <resource name="Sentinel-1 SAR Space Packet Protocol Data Unit S1-IF-ASD-PL-0007" role="Applicable Document" version="13.0">
#  </resource>
#  <resource name="Downlinked Stream" role="Raw Data">
#  <processing name="Raw Data Downlink Channel1 1" start="2021-09-29T09:09:40.570802" stop="2021-09-29T09:09:56.208138" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  </processing>
#  </resource>
#  </processing>
#  </resource>
#  <resource name="Unknown" role="Raw Data">
#  <processing name="Generation of Sentinel-1 SAR Slice L0 product single polarisation" start="2021-09-29T09:30:46.089571" stop="2021-09-29T09:30:47.396981" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <resource name="S-1 Core PDGS S-1 Level-0 Product Format Specifications S1PD.SP.00110.ASTR" role="Applicable Document">
#  </resource>
#  <resource name="Sentinel-1 SAR Space Packet Protocol Data Unit S1-IF-ASD-PL-0007" role="Applicable Document" version="13.0">
#  </resource>
#  <resource name="Downlinked Stream" role="Raw Data">
#  <processing name="Raw Data Downlink Channel2 2" start="2021-09-29T09:09:32.294042" stop="2021-09-29T09:09:51.235736" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  </processing>
#  </resource>
#  </processing>
#  </resource>
#  </processing>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>,
#  <metadataWrap mimeType="text/xml" textInfo="Processing" vocabularyName="SAFE">
#  <xmlData>
#  <processing name="Generation of Sentinel-1 L0 SAR Product, dual polarisation" start="2021-09-29T09:31:05.616464" stop="2021-09-29T09:31:05.742257" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <facility name="PAC1"/>
#  <resource name="S-1 Core PDGS S-1 Level-0 Product Format Specifications S1PD.SP.00110.ASTR" role="Applicable Document">
#  </resource>
#  <resource name="Sentinel-1 SAR Space Packet Protocol Data Unit S1-IF-ASD-PL-0007" role="Applicable Document" version="13.0">
#  </resource>
#  <resource name="Unknown" role="Raw Data">
#  <processing name="Generation of Sentinel-1 SAR Slice L0 product single polarisation" start="2021-09-29T09:30:11.253592" stop="2021-09-29T09:30:12.682501" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <resource name="S-1 Core PDGS S-1 Level-0 Product Format Specifications S1PD.SP.00110.ASTR" role="Applicable Document">
#  </resource>
#  <resource name="Sentinel-1 SAR Space Packet Protocol Data Unit S1-IF-ASD-PL-0007" role="Applicable Document" version="13.0">
#  </resource>
#  <resource name="Downlinked Stream" role="Raw Data">
#  <processing name="Raw Data Downlink Channel1 1" start="2021-09-29T09:09:40.570802" stop="2021-09-29T09:09:56.208138" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  </processing>
#  </resource>
#  </processing>
#  </resource>
#  <resource name="Unknown" role="Raw Data">
#  <processing name="Generation of Sentinel-1 SAR Slice L0 product single polarisation" start="2021-09-29T09:30:46.089571" stop="2021-09-29T09:30:47.396981" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <resource name="S-1 Core PDGS S-1 Level-0 Product Format Specifications S1PD.SP.00110.ASTR" role="Applicable Document">
#  </resource>
#  <resource name="Sentinel-1 SAR Space Packet Protocol Data Unit S1-IF-ASD-PL-0007" role="Applicable Document" version="13.0">
#  </resource>
#  <resource name="Downlinked Stream" role="Raw Data">
#  <processing name="Raw Data Downlink Channel2 2" start="2021-09-29T09:09:32.294042" stop="2021-09-29T09:09:51.235736" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  </processing>
#  </resource>
#  </processing>
#  </resource>
#  </processing>
#  </xmlData>
#  </metadataWrap>,
#  <xmlData>
#  <processing name="Generation of Sentinel-1 L0 SAR Product, dual polarisation" start="2021-09-29T09:31:05.616464" stop="2021-09-29T09:31:05.742257" xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <facility name="PAC1"/>
#  <resource name="S-1 Core PDGS S-1 Level-0 Product Format Specifications S1PD.SP.00110.ASTR" role="Applicable Document">
#  </resource>
#  <resource name="Sentinel-1 SAR Space Packet Protocol Data Unit S1-IF-ASD-PL-0007" role="Applicable Document" version="13.0">
#  </resource>
#  <resource name="Unknown" role="Raw Data">
# ...
#  </footPrint>
#  </frame>
#  </frameSet>
#  </xmlData>,
#  <frameSet xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <frame>
#  <footPrint srsName="http:/www.opengis.net/gml/srs/epsg.xml#4326">
#  <coordinates xmlns="http://www.opengis.net/gml">-18.8993,-39.6777 -20.8323,-40.2064 -21.2389,-37.8639 -19.2949,-37.3641 -18.8993,-39.6777</coordinates>
#  </footPrint>
#  </frame>
#  </frameSet>,
#  <frame>
#  <footPrint srsName="http:/www.opengis.net/gml/srs/epsg.xml#4326">
#  <coordinates xmlns="http://www.opengis.net/gml">-18.8993,-39.6777 -20.8323,-40.2064 -21.2389,-37.8639 -19.2949,-37.3641 -18.8993,-39.6777</coordinates>
#  </footPrint>
#  </frame>,
#  <footPrint srsName="http:/www.opengis.net/gml/srs/epsg.xml#4326">
#  <coordinates xmlns="http://www.opengis.net/gml">-18.8993,-39.6777 -20.8323,-40.2064 -21.2389,-37.8639 -19.2949,-37.3641 -18.8993,-39.6777</coordinates>
#  </footPrint>,
#  <coordinates xmlns="http://www.opengis.net/gml">-18.8993,-39.6777 -20.8323,-40.2064 -21.2389,-37.8639 -19.2949,-37.3641 -18.8993,-39.6777</coordinates>,
#  <metadataObject ID="measurementQualityInformation" category="DMD" classification="DESCRIPTION">
#  <metadataWrap mimeType="text/xml" textInfo="Quality Information" vocabularyName="SAFE">
#  <xmlData>
#  <qualityInformation xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData1</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>
#  </qualityInformation>
#  <qualityInformation xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData2</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>
#  </qualityInformation>
#  </xmlData>
#  </metadataWrap>
#  </metadataObject>,
#  <metadataWrap mimeType="text/xml" textInfo="Quality Information" vocabularyName="SAFE">
#  <xmlData>
#  <qualityInformation xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData1</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>
#  </qualityInformation>
#  <qualityInformation xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData2</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>
#  </qualityInformation>
#  </xmlData>
#  </metadataWrap>,
#  <xmlData>
#  <qualityInformation xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData1</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>
#  </qualityInformation>
#  <qualityInformation xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData2</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>
#  </qualityInformation>
#  </xmlData>,
#  <qualityInformation xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData1</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>
#  </qualityInformation>,
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData1</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>,
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData1</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>,
#  <s1:dataObjectID>measurementData1</s1:dataObjectID>,
#  <s1:numOfElements>51783</s1:numOfElements>,
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>,
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>,
#  <qualityInformation xmlns="http://www.esa.int/safe/sentinel-1.0">
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData2</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>
#  </qualityInformation>,
#  <extension>
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData2</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>
#  </extension>,
#  <s1:qualityProperties>
#  <s1:dataObjectID>measurementData2</s1:dataObjectID>
#  <s1:numOfElements>51783</s1:numOfElements>
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>
#  </s1:qualityProperties>,
#  <s1:dataObjectID>measurementData2</s1:dataObjectID>,
#  <s1:numOfElements>51783</s1:numOfElements>,
#  <s1:numOfMissingElements>0</s1:numOfMissingElements>,
#  <s1:numOfCorruptedElements>0</s1:numOfCorruptedElements>,
#  <metadataObject ID="measurement1Annotation" category="DMD" classification="DESCRIPTION">
#  <dataObjectPointer dataObjectID="measurementAnnotData1"/>
#  </metadataObject>,
#  <dataObjectPointer dataObjectID="measurementAnnotData1"/>,
#  <metadataObject ID="measurement1IndexAnnotation" category="DMD" classification="DESCRIPTION">
#  <dataObjectPointer dataObjectID="measurementIndexData1"/>
#  </metadataObject>,
#  <dataObjectPointer dataObjectID="measurementIndexData1"/>,
#  <metadataObject ID="measurement2Annotation" category="DMD" classification="DESCRIPTION">
#  <dataObjectPointer dataObjectID="measurementAnnotData2"/>
#  </metadataObject>,
#  <dataObjectPointer dataObjectID="measurementAnnotData2"/>,
#  <metadataObject ID="measurement2IndexAnnotation" category="DMD" classification="DESCRIPTION">
#  <dataObjectPointer dataObjectID="measurementIndexData2"/>
#  </metadataObject>,
#  <dataObjectPointer dataObjectID="measurementIndexData2"/>,
#  <metadataObject ID="measurementAnnotationSchema" category="REP" classification="SYNTAX">
#  <metadataReference href="./support/s1-level-0-annot.xsd" locatorType="URL" mimeType="text/xml" vocabularyName="SDF"/>
#  </metadataObject>,
#  <metadataReference href="./support/s1-level-0-annot.xsd" locatorType="URL" mimeType="text/xml" vocabularyName="SDF"/>,
#  <metadataObject ID="measurementIndexAnnotationSchema" category="REP" classification="SYNTAX">
#  <metadataReference href="./support/s1-level-0-index.xsd" locatorType="URL" mimeType="text/xml" vocabularyName="SDF"/>
#  </metadataObject>,
#  <metadataReference href="./support/s1-level-0-index.xsd" locatorType="URL" mimeType="text/xml" vocabularyName="SDF"/>,
#  <metadataObject ID="measurementSchema" category="REP" classification="SYNTAX">
#  <metadataReference href="./support/s1-level-0.xsd" locatorType="URL" mimeType="text/xml" vocabularyName="SDF"/>
#  </metadataObject>,
#  <metadataReference href="./support/s1-level-0.xsd" locatorType="URL" mimeType="text/xml" vocabularyName="SDF"/>,
#  <dataObjectSection>
#  <dataObject ID="measurementAnnotData1" repID="measurementAnnotationSchema">
#  <byteStream mimeType="application/octet-stream" size="1346358">
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342-annot.dat" locatorType="URL" textInfo="Annotation for Measurement Data"/>
#  <checksum checksumName="MD5">be2c6814fdaa857c60ef7b28ef44cdae</checksum>
#  </byteStream>
#  </dataObject>
#  <dataObject ID="measurementAnnotData2" repID="measurementAnnotationSchema">
#  <byteStream mimeType="application/octet-stream" size="1346358">
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342-annot.dat" locatorType="URL" textInfo="Annotation for Measurement Data"/>
#  <checksum checksumName="MD5">5aff5196c3ede79e18d5f0c85ebc7358</checksum>
#  </byteStream>
#  </dataObject>
#  <dataObject ID="measurementData1" repID="measurementSchema">
#  <byteStream mimeType="application/octet-stream" size="905772972">
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342.dat" locatorType="URL" textInfo="Measurement Data Unit"/>
#  <checksum checksumName="MD5">2302171fb8e314712e5232a28e5dbf0c</checksum>
#  </byteStream>
#  </dataObject>
#  <dataObject ID="measurementData2" repID="measurementSchema">
#  <byteStream mimeType="application/octet-stream" size="763394352">
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342.dat" locatorType="URL" textInfo="Measurement Data Unit"/>
#  <checksum checksumName="MD5">8ee5adec8e08d1d6373845b9ef263c69</checksum>
#  </byteStream>
#  </dataObject>
#  <dataObject ID="measurementIndexData1" repID="measurementIndexAnnotationSchema">
#  <byteStream mimeType="application/octet-stream" size="1908">
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342-index.dat" locatorType="URL" textInfo="Index for Measurement Data"/>
#  <checksum checksumName="MD5">83f038d8d91099ddbc9a6ae29e4b34ce</checksum>
#  </byteStream>
#  </dataObject>
#  <dataObject ID="measurementIndexData2" repID="measurementIndexAnnotationSchema">
#  <byteStream mimeType="application/octet-stream" size="1908">
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342-index.dat" locatorType="URL" textInfo="Index for Measurement Data"/>
#  <checksum checksumName="MD5">501dc9466888f8b5cadb1b77290134da</checksum>
#  </byteStream>
#  </dataObject>
#  </dataObjectSection>,
#  <dataObject ID="measurementAnnotData1" repID="measurementAnnotationSchema">
#  <byteStream mimeType="application/octet-stream" size="1346358">
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342-annot.dat" locatorType="URL" textInfo="Annotation for Measurement Data"/>
#  <checksum checksumName="MD5">be2c6814fdaa857c60ef7b28ef44cdae</checksum>
#  </byteStream>
#  </dataObject>,
#  <byteStream mimeType="application/octet-stream" size="1346358">
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342-annot.dat" locatorType="URL" textInfo="Annotation for Measurement Data"/>
#  <checksum checksumName="MD5">be2c6814fdaa857c60ef7b28ef44cdae</checksum>
#  </byteStream>,
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342-annot.dat" locatorType="URL" textInfo="Annotation for Measurement Data"/>,
#  <checksum checksumName="MD5">be2c6814fdaa857c60ef7b28ef44cdae</checksum>,
#  <dataObject ID="measurementAnnotData2" repID="measurementAnnotationSchema">
#  <byteStream mimeType="application/octet-stream" size="1346358">
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342-annot.dat" locatorType="URL" textInfo="Annotation for Measurement Data"/>
#  <checksum checksumName="MD5">5aff5196c3ede79e18d5f0c85ebc7358</checksum>
#  </byteStream>
#  </dataObject>,
#  <byteStream mimeType="application/octet-stream" size="1346358">
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342-annot.dat" locatorType="URL" textInfo="Annotation for Measurement Data"/>
#  <checksum checksumName="MD5">5aff5196c3ede79e18d5f0c85ebc7358</checksum>
#  </byteStream>,
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342-annot.dat" locatorType="URL" textInfo="Annotation for Measurement Data"/>,
#  <checksum checksumName="MD5">5aff5196c3ede79e18d5f0c85ebc7358</checksum>,
#  <dataObject ID="measurementData1" repID="measurementSchema">
#  <byteStream mimeType="application/octet-stream" size="905772972">
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342.dat" locatorType="URL" textInfo="Measurement Data Unit"/>
#  <checksum checksumName="MD5">2302171fb8e314712e5232a28e5dbf0c</checksum>
#  </byteStream>
#  </dataObject>,
#  <byteStream mimeType="application/octet-stream" size="905772972">
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342.dat" locatorType="URL" textInfo="Measurement Data Unit"/>
#  <checksum checksumName="MD5">2302171fb8e314712e5232a28e5dbf0c</checksum>
#  </byteStream>,
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342.dat" locatorType="URL" textInfo="Measurement Data Unit"/>,
#  <checksum checksumName="MD5">2302171fb8e314712e5232a28e5dbf0c</checksum>,
#  <dataObject ID="measurementData2" repID="measurementSchema">
#  <byteStream mimeType="application/octet-stream" size="763394352">
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342.dat" locatorType="URL" textInfo="Measurement Data Unit"/>
#  <checksum checksumName="MD5">8ee5adec8e08d1d6373845b9ef263c69</checksum>
#  </byteStream>
#  </dataObject>,
#  <byteStream mimeType="application/octet-stream" size="763394352">
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342.dat" locatorType="URL" textInfo="Measurement Data Unit"/>
#  <checksum checksumName="MD5">8ee5adec8e08d1d6373845b9ef263c69</checksum>
#  </byteStream>,
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342.dat" locatorType="URL" textInfo="Measurement Data Unit"/>,
#  <checksum checksumName="MD5">8ee5adec8e08d1d6373845b9ef263c69</checksum>,
#  <dataObject ID="measurementIndexData1" repID="measurementIndexAnnotationSchema">
#  <byteStream mimeType="application/octet-stream" size="1908">
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342-index.dat" locatorType="URL" textInfo="Index for Measurement Data"/>
#  <checksum checksumName="MD5">83f038d8d91099ddbc9a6ae29e4b34ce</checksum>
#  </byteStream>
#  </dataObject>,
#  <byteStream mimeType="application/octet-stream" size="1908">
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342-index.dat" locatorType="URL" textInfo="Index for Measurement Data"/>
#  <checksum checksumName="MD5">83f038d8d91099ddbc9a6ae29e4b34ce</checksum>
#  </byteStream>,
#  <fileLocation href="./s1b-iw-raw-s-vh-20210929t080443-20210929t080515-028910-037342-index.dat" locatorType="URL" textInfo="Index for Measurement Data"/>,
#  <checksum checksumName="MD5">83f038d8d91099ddbc9a6ae29e4b34ce</checksum>,
#  <dataObject ID="measurementIndexData2" repID="measurementIndexAnnotationSchema">
#  <byteStream mimeType="application/octet-stream" size="1908">
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342-index.dat" locatorType="URL" textInfo="Index for Measurement Data"/>
#  <checksum checksumName="MD5">501dc9466888f8b5cadb1b77290134da</checksum>
#  </byteStream>
#  </dataObject>,
#  <byteStream mimeType="application/octet-stream" size="1908">
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342-index.dat" locatorType="URL" textInfo="Index for Measurement Data"/>
#  <checksum checksumName="MD5">501dc9466888f8b5cadb1b77290134da</checksum>
#  </byteStream>,
#  <fileLocation href="./s1b-iw-raw-s-vv-20210929t080443-20210929t080515-028910-037342-index.dat" locatorType="URL" textInfo="Index for Measurement Data"/>,
#  <checksum checksumName="MD5">501dc9466888f8b5cadb1b77290134da</checksum>]

# %% [markdown]
# Now we will download a data set

# %%
import requests
# We start by getting the metadata

uri = "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/?$format=json&$expand=Attributes"

metadata = requests.get(uri, auth=(user, password))
metadata.json()['d']
# Out:
# {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/('659851c9-6b5e-483f-97aa-972c3823abe2')",
#   'uri': "https://scihub.copernicus.eu/dhus/odata/v1/('659851c9-6b5e-483f-97aa-972c3823abe2')",
#   'type': 'DHuS.Product',
#   'content_type': 'application/octet-stream',
#   'media_src': "https://scihub.copernicus.eu/dhus/odata/v1/('659851c9-6b5e-483f-97aa-972c3823abe2')/$value",
#   'edit_media': "https://scihub.copernicus.eu/dhus/odata/v1/('659851c9-6b5e-483f-97aa-972c3823abe2')/$value"},
#  'Id': '659851c9-6b5e-483f-97aa-972c3823abe2',
#  'Name': 'S1B_IW_GRDH_1SDV_20211004T170346_20211004T170411_028988_037598_E3A6',
#  'ContentType': 'application/octet-stream',
#  'ContentLength': '867511586',
#  'ChildrenNumber': '2',
#  'Value': None,
#  'CreationDate': '/Date(1633429921558)/',
#  'IngestionDate': '/Date(1633429813213)/',
#  'ModificationDate': '/Date(1633429921558)/',
#  'EvictionDate': None,
#  'Online': True,
#  'OnDemand': False,
#  'ContentDate': {'__metadata': {'type': 'DHuS.TimeRange'},
#   'Start': '/Date(1633367026553)/',
#   'End': '/Date(1633367051552)/'},
#  'Checksum': {'__metadata': {'type': 'DHuS.Checksum'},
#   'Algorithm': 'MD5',
#   'Value': 'ad482ebb8f8ef7a81e185919953d6948'},
#  'ContentGeometry': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>-22.724472,21.103437 -22.145626,23.553726 -23.639910,23.970881 -24.226313,21.495274 -22.724472,21.103437</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#  'Products': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/('659851c9-6b5e-483f-97aa-972c3823abe2')/Products"}},
#  'Nodes': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/('659851c9-6b5e-483f-97aa-972c3823abe2')/Nodes"}},
#  'Attributes': {'results': [{'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Acquisition%20Type')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Acquisition%20Type')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Acquisition Type',
#     'Name': 'Acquisition Type',
#     'ContentType': 'text/plain',
#     'ContentLength': '7',
#     'Value': 'NOMINAL',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Carrier%20rocket')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Carrier%20rocket')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Carrier rocket',
#     'Name': 'Carrier rocket',
#     'ContentType': 'text/plain',
#     'ContentLength': '5',
#     'Value': 'Soyuz',
#     'Category': 'platform'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Cycle%20number')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Cycle%20number')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Cycle number',
#     'Name': 'Cycle number',
#     'ContentType': 'text/plain',
#     'ContentLength': '3',
#     'Value': '172',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Date')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Date')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Date',
#     'Name': 'Date',
#     'ContentType': 'text/plain',
#     'ContentLength': '24',
#     'Value': '2021-10-04T17:03:46.553Z',
#     'Category': 'summary'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Filename')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Filename')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Filename',
#     'Name': 'Filename',
#     'ContentType': 'text/plain',
#     'ContentLength': '72',
#     'Value': 'S1B_IW_GRDH_1SDV_20211004T170346_20211004T170411_028988_037598_E3A6.SAFE',
#     'Category': 'summary'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Footprint')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Footprint')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Footprint',
#     'Name': 'Footprint',
#     'ContentType': 'text/plain',
#     'ContentLength': '369',
#     'Value': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>-22.724472,21.103437 -22.145626,23.553726 -23.639910,23.970881 -24.226313,21.495274 -22.724472,21.103437</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Format')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Format')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Format',
#     'Name': 'Format',
#     'ContentType': 'text/plain',
#     'ContentLength': '4',
#     'Value': 'SAFE',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Identifier')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Identifier')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Identifier',
#     'Name': 'Identifier',
#     'ContentType': 'text/plain',
#     'ContentLength': '67',
#     'Value': 'S1B_IW_GRDH_1SDV_20211004T170346_20211004T170411_028988_037598_E3A6',
#     'Category': 'summary'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Ingestion%20Date')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Ingestion%20Date')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Ingestion Date',
#     'Name': 'Ingestion Date',
#     'ContentType': 'text/plain',
#     'ContentLength': '24',
#     'Value': '2021-10-05T10:30:13.213Z',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Instrument',
#     'Name': 'Instrument',
#     'ContentType': 'text/plain',
#     'ContentLength': '5',
#     'Value': 'SAR-C',
#     'Category': 'summary'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument%20abbreviation')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument%20abbreviation')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Instrument abbreviation',
#     'Name': 'Instrument abbreviation',
#     'ContentType': 'text/plain',
#     'ContentLength': '9',
#     'Value': 'SAR-C SAR',
#     'Category': 'instrument'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument%20description')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument%20description')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Instrument description',
#     'Name': 'Instrument description',
#     'ContentType': 'text/plain',
#     'ContentLength': '145',
#     'Value': '<a target="_blank" href="https://sentinel.esa.int/web/sentinel/missions/sentinel-1">https://sentinel.esa.int/web/sentinel/missions/sentinel-1</a>',
#     'Category': 'instrument'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument%20description%20text')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument%20description%20text')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Instrument description text',
#     'Name': 'Instrument description text',
#     'ContentType': 'text/plain',
#     'ContentLength': '1143',
#     'Value': 'The SAR Antenna Subsystem (SAS) is developed and build by AstriumGmbH. It is a large foldable planar phased array antenna, which isformed by a centre panel and two antenna side wings. In deployedconfiguration the antenna has an overall aperture of 12.3 x 0.84 m.The antenna provides a fast electronic scanning capability inazimuth and elevation and is based on low loss and highly stablewaveguide radiators build in carbon fibre technology, which arealready successfully used by the TerraSAR-X radar imaging mission.The SAR Electronic Subsystem (SES) is developed and build byAstrium Ltd. It provides all radar control, IF/ RF signalgeneration and receive data handling functions for the SARInstrument. The fully redundant SES is based on a channelisedarchitecture with one transmit and two receive chains, providing amodular approach to the generation and reception of wide-bandsignals and the handling of multi-polarisation modes. One keyfeature is the implementation of the Flexible Dynamic BlockAdaptive Quantisation (FD-BAQ) data compression concept, whichallows an efficient use of on-board storage resources and minimisesdownlink times.',
#     'Category': ''},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument%20mode')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument%20mode')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Instrument mode',
#     'Name': 'Instrument mode',
#     'ContentType': 'text/plain',
#     'ContentLength': '2',
#     'Value': 'IW',
#     'Category': 'instrument'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument%20name')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument%20name')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Instrument name',
#     'Name': 'Instrument name',
#     'ContentType': 'text/plain',
#     'ContentLength': '33',
#     'Value': 'Synthetic Aperture Radar (C-band)',
#     'Category': 'instrument'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument%20swath')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Instrument%20swath')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Instrument swath',
#     'Name': 'Instrument swath',
#     'ContentType': 'text/plain',
#     'ContentLength': '2',
#     'Value': 'IW',
#     'Category': 'instrument'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('JTS%20footprint')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('JTS%20footprint')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'JTS footprint',
#     'Name': 'JTS footprint',
#     'ContentType': 'text/plain',
#     'ContentLength': '126',
#     'Value': 'MULTIPOLYGON (((21.495274 -24.226313, 23.970881 -23.63991, 23.553726 -22.145626, 21.103437 -22.724472, 21.495274 -24.226313)))',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Launch%20date')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Launch%20date')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Launch date',
#     'Name': 'Launch date',
#     'ContentType': 'text/plain',
#     'ContentLength': '16',
#     'Value': 'April 25th, 2016',
#     'Category': 'platform'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Mission%20datatake%20id')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Mission%20datatake%20id')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Mission datatake id',
#     'Name': 'Mission datatake id',
#     'ContentType': 'text/plain',
#     'ContentLength': '6',
#     'Value': '226712',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Mission%20type')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Mission%20type')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Mission type',
#     'Name': 'Mission type',
#     'ContentType': 'text/plain',
#     'ContentLength': '17',
#     'Value': 'Earth observation',
#     'Category': 'platform'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Mode')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Mode')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Mode',
#     'Name': 'Mode',
#     'ContentType': 'text/plain',
#     'ContentLength': '2',
#     'Value': 'IW',
#     'Category': 'summary'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('NSSDC%20identifier')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('NSSDC%20identifier')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'NSSDC identifier',
#     'Name': 'NSSDC identifier',
#     'ContentType': 'text/plain',
#     'ContentLength': '9',
#     'Value': '2016-025A',
#     'Category': 'platform'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Operator')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Operator')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Operator',
#     'Name': 'Operator',
#     'ContentType': 'text/plain',
#     'ContentLength': '21',
#     'Value': 'European Space Agency',
#     'Category': 'platform'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Orbit%20number%20%28start%29')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Orbit%20number%20%28start%29')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Orbit number (start)',
#     'Name': 'Orbit number (start)',
#     'ContentType': 'text/plain',
#     'ContentLength': '5',
#     'Value': '28988',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Orbit%20number%20%28stop%29')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Orbit%20number%20%28stop%29')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Orbit number (stop)',
#     'Name': 'Orbit number (stop)',
#     'ContentType': 'text/plain',
#     'ContentLength': '5',
#     'Value': '28988',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Pass%20direction')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Pass%20direction')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Pass direction',
#     'Name': 'Pass direction',
#     'ContentType': 'text/plain',
#     'ContentLength': '9',
#     'Value': 'ASCENDING',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Phase%20identifier')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Phase%20identifier')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Phase identifier',
#     'Name': 'Phase identifier',
#     'ContentType': 'text/plain',
#     'ContentLength': '1',
#     'Value': '1',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Polarisation')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Polarisation')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Polarisation',
#     'Name': 'Polarisation',
#     'ContentType': 'text/plain',
#     'ContentLength': '5',
#     'Value': 'VV VH',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Product%20class')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Product%20class')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Product class',
#     'Name': 'Product class',
#     'ContentType': 'text/plain',
#     'ContentLength': '1',
#     'Value': 'S',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Product%20class%20description')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Product%20class%20description')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Product class description',
#     'Name': 'Product class description',
#     'ContentType': 'text/plain',
#     'ContentLength': '23',
#     'Value': 'SAR Standard L1 Product',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Product%20composition')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Product%20composition')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Product composition',
#     'Name': 'Product composition',
#     'ContentType': 'text/plain',
#     'ContentLength': '5',
#     'Value': 'Slice',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Product%20level')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Product%20level')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Product level',
#     'Name': 'Product level',
#     'ContentType': 'text/plain',
#     'ContentLength': '2',
#     'Value': 'L1',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Product%20type')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Product%20type')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Product type',
#     'Name': 'Product type',
#     'ContentType': 'text/plain',
#     'ContentLength': '3',
#     'Value': 'GRD',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Relative%20orbit%20%28start%29')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Relative%20orbit%20%28start%29')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Relative orbit (start)',
#     'Name': 'Relative orbit (start)',
#     'ContentType': 'text/plain',
#     'ContentLength': '2',
#     'Value': '87',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Relative%20orbit%20%28stop%29')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Relative%20orbit%20%28stop%29')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Relative orbit (stop)',
#     'Name': 'Relative orbit (stop)',
#     'ContentType': 'text/plain',
#     'ContentLength': '2',
#     'Value': '87',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Resolution')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Resolution')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Resolution',
#     'Name': 'Resolution',
#     'ContentType': 'text/plain',
#     'ContentLength': '4',
#     'Value': 'High',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Satellite')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Satellite')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Satellite',
#     'Name': 'Satellite',
#     'ContentType': 'text/plain',
#     'ContentLength': '10',
#     'Value': 'Sentinel-1',
#     'Category': 'summary'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Satellite%20description')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Satellite%20description')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Satellite description',
#     'Name': 'Satellite description',
#     'ContentType': 'text/plain',
#     'ContentLength': '145',
#     'Value': '<a target="_blank" href="https://sentinel.esa.int/web/sentinel/missions/sentinel-1">https://sentinel.esa.int/web/sentinel/missions/sentinel-1</a>',
#     'Category': 'platform'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Satellite%20name')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Satellite%20name')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Satellite name',
#     'Name': 'Satellite name',
#     'ContentType': 'text/plain',
#     'ContentLength': '10',
#     'Value': 'Sentinel-1',
#     'Category': 'platform'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Satellite%20number')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Satellite%20number')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Satellite number',
#     'Name': 'Satellite number',
#     'ContentType': 'text/plain',
#     'ContentLength': '1',
#     'Value': 'B',
#     'Category': 'platform'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Sensing%20start')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Sensing%20start')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Sensing start',
#     'Name': 'Sensing start',
#     'ContentType': 'text/plain',
#     'ContentLength': '24',
#     'Value': '2021-10-04T17:03:46.553Z',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Sensing%20stop')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Sensing%20stop')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Sensing stop',
#     'Name': 'Sensing stop',
#     'ContentType': 'text/plain',
#     'ContentLength': '24',
#     'Value': '2021-10-04T17:04:11.552Z',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Size')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Size')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Size',
#     'Name': 'Size',
#     'ContentType': 'text/plain',
#     'ContentLength': '7',
#     'Value': '1.64 GB',
#     'Category': 'summary'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Slice%20number')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Slice%20number')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Slice number',
#     'Name': 'Slice number',
#     'ContentType': 'text/plain',
#     'ContentLength': '1',
#     'Value': '2',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Start%20relative%20orbit%20number')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Start%20relative%20orbit%20number')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Start relative orbit number',
#     'Name': 'Start relative orbit number',
#     'ContentType': 'text/plain',
#     'ContentLength': '2',
#     'Value': '87',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Status')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Status')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Status',
#     'Name': 'Status',
#     'ContentType': 'text/plain',
#     'ContentLength': '8',
#     'Value': 'ARCHIVED',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Stop%20relative%20orbit%20number')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Stop%20relative%20orbit%20number')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Stop relative orbit number',
#     'Name': 'Stop relative orbit number',
#     'ContentType': 'text/plain',
#     'ContentLength': '2',
#     'Value': '87',
#     'Category': 'product'},
#    {'__metadata': {'id': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Timeliness%20Category')",
#      'uri': "https://scihub.copernicus.eu/dhus/odata/v1/Products('659851c9-6b5e-483f-97aa-972c3823abe2')/Attributes('Timeliness%20Category')",
#      'type': 'DHuS.Attribute'},
#     'Id': 'Timeliness Category',
#     'Name': 'Timeliness Category',
#     'ContentType': 'text/plain',
#     'ContentLength': '8',
#     'Value': 'Fast-24h',
#     'Category': 'product'}]},
#  'Class': {'__deferred': {'uri': "https://scihub.copernicus.eu/dhus/odata/v1/('659851c9-6b5e-483f-97aa-972c3823abe2')/Class"}}}

# %%
#Then we get the media source link
uri = "https://scihub.copernicus.eu/dhus/odata/v1/('659851c9-6b5e-483f-97aa-972c3823abe2')/$value"+"?$format=json"
print(uri)
#And download it
product = requests.get(uri,stream=True, auth=(user, password))
product.json()
# Out:
# https://scihub.copernicus.eu/dhus/odata/v1/('659851c9-6b5e-483f-97aa-972c3823abe2')/$value?$format=json
# {'error': {'code': None,
#   'message': {'lang': 'en',
#    'value': "Could not match segment: '('659851c9-6b5e-483f-97aa-972c3823abe2')'."}}}

# %% [markdown]
# # Sources:
#
# -[1]: https://scihub.copernicus.eu/
#
# -[2]: https://sentinels.copernicus.eu/web/sentinel/missions/sentinel-1
#
# -[3]: https://sentinels.copernicus.eu/web/sentinel/missions/sentinel-2
#
# -[4]: https://sentinels.copernicus.eu/web/sentinel/missions/sentinel-3
#
# -[5]: https://sentinels.copernicus.eu/web/sentinel/missions/sentinel-5p
